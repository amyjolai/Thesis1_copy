# %%
#!/usr/bin/python
# Read in bonds and angles, get rid of capping groups at line 8, 16, 56+
# look at biggest diff between bonds and angles (where and which groups, and what does this mean wrt capping group distorting the dimer)

import numpy as np
import pandas as pd
import csv
import pandas as pd
import re

out=open("diff_ang.txt","w+")

home="C:\\Users\\amyjo\\Desktop\\raven-dimers-trimers_working copy\\"

CH3CH3=open(home+"CH3_CH3\\NC3_3\\bonds_angles.txt",'r')
CH3OH=open(home+"NC3_3\\bonds_angles.txt",'r')
OHCH3=open(home+"OH_CH3\\NC3_3\\bonds_angles.txt",'r')

# if [CH3CH3==True]:
#     print ("yes")
# else:
#         print ("no")
# Out:
# yes

# %%
CC=pd.read_csv(CH3CH3,index_col=0)
# CO=
# OC=
