# %%
import pandas as pd
import re

out=open("text.txt","w+")
dimer1="C:\\Users\\amyjo\\Google Drive\\NC_locals\\Thesis_data\\Chap1-Building_the_model\\dimer\\Total_Energies_CH3_CH3.txt"

f=open(dimer1,'r')
#data=(f.read())
data=(f.read()).split('\n')

#print (data,type(data))

#pd.DataFrame(data=None, index=None, columns=None, dtype=None, copy=False)
df=pd.DataFrame(data)

# If you give them another two column names, it'll split into another 2 columns (i.e. 3 total)
#df[['Index','Energy']] = df[0].str.split("=",expand=True)

# Multiple column splits, first by "=" then ":"
#df=df[0].str.split('=|:',expand=True).add_prefix('Number_')

# Splitting into just 2 columns, from the first one - have to name your first column the same
df[[0,"Energy"]]=df[0].str.split('=',expand=True)

df["Energy"]=df["Energy"].str.strip()

df[["Energy","Units"]] = df["Energy"].str.split(" ",n=1,expand=True)

# This didn't work: Drop the empty rows (axis=0 is row, =1 is column)
#df.dropna(axis=0, how='all', thresh=None, subset=None, inplace=True)

#out.write(str(df))
#print(df.iloc[:15])
#print (df["Energy"])

print (df)
f.close()
# Out:
#                                                 0          Energy  \
# 0                                           from:            None
# 1     /mnt/d/Backups/raven-dimers-trimers/CH3_CH3            None
# 2                                                            None
# 3                                                            None
# 4                           NC0_0/NC0_0tworun.out            None
# 5                           SCF Done:  E(RB3LYP)   -1376.95583928
# 6                           Zero-point correction        0.424978
# 7                    Thermal correction to Energy        0.452003
# 8                  Thermal correction to Enthalpy        0.452947
# 9         Thermal correction to Gibbs Free Energy        0.367646
# 10      Sum of electronic and zero-point Energies    -1376.530861
# 11         Sum of electronic and thermal Energies    -1376.503836
# 12       Sum of electronic and thermal Enthalpies    -1376.502892
# 13    Sum of electronic and thermal Free Energies    -1376.588193
# 14                                                           None
# 15                                                           None
# 16                          NC0_2/NC0_2tworun.out            None
# 17                          SCF Done:  E(RB3LYP)   -1581.47062820
# 18                          Zero-point correction        0.427484
# 19                   Thermal correction to Energy        0.456628
# 20                 Thermal correction to Enthalpy        0.457572
# 21        Thermal correction to Gibbs Free Energy        0.366769
# 22      Sum of electronic and zero-point Energies    -1581.043144
# 23         Sum of electronic and thermal Energies    -1581.014000
# 24       Sum of electronic and thermal Enthalpies    -1581.013056
# 25    Sum of electronic and thermal Free Energies    -1581.103860
# 26                                                           None
# 27                                                           None
# 28                  NC2-6_2-6/NC2-6_2-6tworun.out            None
# 29                          SCF Done:  E(RB3LYP)   -2195.03739961
# ..                                            ...             ...
# 95         Sum of electronic and thermal Energies    -1785.527982
# 96       Sum of electronic and thermal Enthalpies    -1785.527038
# 97    Sum of electronic and thermal Free Energies    -1785.629113
# 98                                                           None
# 99                                                           None
# 100                     NC3_2-6/NC3_2-6tworun.out            None
# 101                         SCF Done:  E(RB3LYP)   -2399.55374730
# 102                         Zero-point correction        0.433303
# 103                  Thermal correction to Energy        0.473186
# 104                Thermal correction to Enthalpy        0.474130
# 105       Thermal correction to Gibbs Free Energy        0.351338
# 106     Sum of electronic and zero-point Energies    -2399.120445
# 107        Sum of electronic and thermal Energies    -2399.080561
# 108      Sum of electronic and thermal Enthalpies    -2399.079617
# 109   Sum of electronic and thermal Free Energies    -2399.202410
# 110                                                          None
# 111                                                          None
# 112                         NC3_3/NC3_3tworun.out            None
# 113                         SCF Done:  E(RB3LYP)   -2604.07324979
# 114                         Zero-point correction        0.434743
# 115                  Thermal correction to Energy        0.477194
# 116                Thermal correction to Enthalpy        0.478139
# 117       Thermal correction to Gibbs Free Energy        0.348354
# 118     Sum of electronic and zero-point Energies    -2603.638507
# 119        Sum of electronic and thermal Energies    -2603.596055
# 120      Sum of electronic and thermal Enthalpies    -2603.595111
# 121   Sum of electronic and thermal Free Energies    -2603.724896
# 122                                                          None
# 123                                                          None
# 124                                                          None
#
#                           Units
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                          None
# 5        A.U. after    1 cycles
# 6            (Hartree/Particle)
# 7                          None
# 8                          None
# 9                          None
# 10                         None
# 11                         None
# 12                         None
# 13                         None
# 14                         None
# 15                         None
# 16                         None
# 17       A.U. after    1 cycles
# 18           (Hartree/Particle)
# 19                         None
# 20                         None
# 21                         None
# 22                         None
# 23                         None
# 24                         None
# 25                         None
# 26                         None
# 27                         None
# 28                         None
# 29       A.U. after    2 cycles
# ..                          ...
# 95                         None
# 96                         None
# 97                         None
# 98                         None
# 99                         None
# 100                        None
# 101      A.U. after    2 cycles
# 102          (Hartree/Particle)
# 103                        None
# 104                        None
# 105                        None
# 106                        None
# 107                        None
# 108                        None
# 109                        None
# 110                        None
# 111                        None
# 112                        None
# 113      A.U. after    2 cycles
# 114          (Hartree/Particle)
# 115                        None
# 116                        None
# 117                        None
# 118                        None
# 119                        None
# 120                        None
# 121                        None
# 122                        None
# 123                        None
# 124                        None
#
# [125 rows x 3 columns]
