# %%
#import pandas as pd
from pandas import *
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import csv

nb="Capping_groups.ipynb"

# %%
dCH3_CH3="C:/Users\\amyjo\\Google Drive\\NC_locals\\Thesis_data\\Chap1-Building_the_model\\dimer\\Total_Energies_CH3_CH3.txt"
data = read_table(dCH3_CH3, header=None,engine='python', sep="\s*")

data

# names = []
# values = []



# with open(dCH3_CH3, 'r') as infile:
#     csv_reader = csv.reader(infile, delimiter=' ') 
#     for line in csv_reader:
#         print (line)
# #        names.append(line[0])
#         #values.append(line[1])
# infile.close()

# print (names)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-07f2299c64ad> in <module>()
#       1 dCH3_CH3="C:/Users\\amyjo\\Google Drive\\NC_locals\\Thesis_data\\Chap1-Building_the_model\\dimer\\Total_Energies_CH3_CH3.txt"
# ----> 2 data = read_table(dCH3_CH3, header=None,engine='python', sep="\s*")
#       3
#       4 data
#       5
#
# ...

# %%
# Add to the list of "extra credit" tasks to do

bt=open("bonus_tasks.txt","a+")

cwd = os.getcwd()

#bt.write("From "+cwd+nb+":\n")

print("From "+cwd+nb+":\n")
# Out:
# From C:\Users\amyjo\Documents\Thesis1_copy\Jupyter_notebooksCapping_groups.ipynb:

# %%
# Source file path. Doubel slashes needed for the escape, in windows
source="C:/Users\\amyjo\\Google Drive\\NC_locals\\Thesis_data\\Chap1-Building_the_model\\"

# %%
# txt to csv pre-processing

# files=source+"\*\*.txt"

# for file in files:
#     out_csv=(file.split(.))
#     joined='|'.join(file.split())
    

# d_txt_CH3_CH3=open("C:/Users\amyjo\Google Drive\NC_locals\Thesis_data\Chap1-Building_the_model\dimer\Total_Energies_CH3_CH3.txt", sep ="  ", header=None) 
# #dCH3_OH=pd.read_csv("Total_Energies_CH3_OH.txt", sep ="  ", header=None) 
#dOH_CH3=pd.read_csv("Total_Energies_OH_CH3.txt", sep ="  ", header=None)
# Out:
#   File "<ipython-input-21-3a545c78edd8>", line 6
#     d_txt_CH3_CH3=open("C:/Users\amyjo\Google Drive\NC_locals\Thesis_data\Chap1-Building_the_model\dimer\Total_Energies_CH3_CH3.txt", sep ="  ", header=None)
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 27-28: malformed \N character escape

# %%
#Read in the monomer files for hydroxy capped and CH3 capped, and pluck out all Free energies

#mCH3_CH3=pd.read_csv(".txt", sep ="", header=None) 
#mCH3_OH=pd.read_csv(".txt", sep ="", header=None) 
#mOH_CH3=pd.read_csv(".txt", sep ="", header=None)

# %%
#Plot numbers in a big table, divided by capping group. (Don't think I considered solvent at thist stage)

# %%
#bt.write(" Repeat capping group and system size comparisons in solvent too.\n")

# %%
#Read in the dimer files for hydroxy capped and CH3 capped, and pluck out all Free energies
#dCH3_CH3=pd.read_csv(r"C:/Users\amyjo\Google Drive\NC_locals\Thesis_data\Chap1-Building_the_model\dimer\Total_Energies_CH3_CH3.txt", sep=r"\s*",engine='python', header=None)
dCH3_CH3=pd.read_csv(r"C:/Users\amyjo\Google Drive\NC_locals\Thesis_data\Chap1-Building_the_model\dimer\Total_Energies_CH3_CH3.txt")
#dCH3_CH3=pd.read_csv("Total_Energies_CH3_CH3.txt", sep ="  ", header=None) 
#dCH3_OH=pd.read_csv("Total_Energies_CH3_OH.txt", sep ="  ", header=None) 
#dOH_CH3=pd.read_csv("Total_Energies_OH_CH3.txt", sep ="  ", header=None)

# %%
#Read in the trimer files for hydroxy capped and CH3 capped, and pluck out all Free energies
tCH3_CH3=pd.read_csv(".txt", sep ="", header=None) 
tCH3_OH=pd.read_csv(".txt", sep ="", header=None) 
tOH_CH3=pd.read_csv(".txt", sep ="", header=None)

# %%
dCH3_CH3.head()
# Out:
#                                                from:
# 0        /mnt/d/Backups/raven-dimers-trimers/CH3_CH3
# 1                              NC0_0/NC0_0tworun.out
# 2   SCF Done:  E(RB3LYP) =  -1376.95583928     A....
# 3   Zero-point correction=                       ...
# 4   Thermal correction to Energy=                ...
