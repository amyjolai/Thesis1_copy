# %%
import matplotlib.pyplot as plt
import numpy as np

#path_to="C:/Users/amyjo/Google Drive/NC_locals/Mech_Monomers/H-O-N_scans/floppy_NO2-C2/"
path_to="C:/Users/amyjo/Google Drive/NC_locals/Analysis Sheets/"

# %%
# strx = "1.39,1.49,1.59,1.69,1.79,1.89,1.99,2.09,2.19,2.29,2.39,2.49,2.59,2.69,2.79,2.89,2.99,3.09,3.19,3.29,3.39,3.49,3.59,3.69,3.79,3.89,3.99,4.09,4.19,4.29,4.39,4.49,4.59,4.69,4.79,4.89,4.99,5.09,5.19,5.29,5.39"
# arx = np.fromstring(strx, dtype=int, sep=',')
# #print(strx.split())
# print(arx)
# Out:
# [1]

# %%
X, Y = [], []
for line in open(path_to+'floppy_NO2-C2-scan_data.txt', 'r'):
  values = [float(s) for s in line.split('\t')]
  X.append(values[0])
  Y.append(values[1])

plt.plot(X, Y)
plt.show()

# %%
# file=path_to+"floppy_NO2-C2-scan.txt"
# #x, y = np.loadtxt(path_to+'floppy_NO2-C2-scan.txt', delimiter='\t', unpack=True)

# f=open(file,"r")
# lines=f.readlines()
# resultx=[]
# resulty=[]
# for line in lines:
# #   print(line+",")
#     resultx.append(line.split()[0])
#     resulty.append(line.split()[1])
# f.close()

# #print(lines)

# #print(resultx)

# print("x="+str(resultx))
# print("y="+str(resulty))

# #plt.plot(x,y, label='Loaded from file!')

# #x = np.linspace(0, 2, 100)

# #plt.plot(x, x, label='linear')
# #plt.plot(x, x**2, label='quadratic')
# #plt.plot(x, x**3, label='cubic')

# plt.plot(resultx,resulty,label='Scan Coordinate')
# #plt.plot(x, x**3, label='cubic')
# Out:
# x=['1.3923300000', '1.4923300000', '1.5923300000', '1.6923300000', '1.7923300000', '1.8923300000', '1.9923300000', '2.0923300000', '2.1923300000', '2.2923300000', '2.3923300000', '2.4923300000', '2.5923300000', '2.6923300000', '2.7923300000', '2.8923300000', '2.9923300000', '3.0923300000', '3.1923300000', '3.2923300000', '3.3923300000', '3.4923300000', '3.5923300000', '3.6923300000', '3.7923300000', '3.8923300000', '3.9923300000', '4.0923300000', '4.1923300000', '4.2923300000', '4.3923300000', '4.4923300000', '4.5923300000', '4.6923300000', '4.7923300000', '4.8923300000', '4.9923300000', '5.0923300000', '5.1923300000', '5.2923300000', '5.3923300000']
# ...

# %%
# #plt.xlabel(resultx,resulty,label='Scan Coordinate')
# #plt.xlabel(str(resultx),label='Scan Coordinate')
# #plt.ylabel(str(resulty),label='Total Energy (Hartree)')
# plt.title('Scan of Total Energy')
# plt.legend()
# plt.show()
